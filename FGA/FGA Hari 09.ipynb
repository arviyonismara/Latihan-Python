# %%
elem_1 = elem_2 = 1

# %%
elem_1
# Out:
# 1

# %%
elem_2
# Out:
# 1

# %%
elem_1 = 3

# %%
elem_2
# Out:
# 1

# %%
elem_2 = 5

# %%
elem_1
# Out:
# 3

# %% [markdown]
# # Fibonaci Versi 1

# %%
def fib(n):
    if n < 1:
        return None
    if n < 3:
        return 1

    elem_1 = elem_2 = 1
    the_sum = 0
    for i in range(3, n + 1):
        the_sum = elem_1 + elem_2
        elem_1, elem_2 = elem_2, the_sum
    return the_sum


for n in range(1, 10):  # testing
    print(n, "->", fib(n))
# Out:
# 1 -> 1
# 2 -> 1
# 3 -> 2
# 4 -> 3
# 5 -> 5
# 6 -> 8
# 7 -> 13
# 8 -> 21
# 9 -> 34

# %% [markdown]
# # Fibonaci Versi 2

# %%
def fib2(n):
    if n < 1:
        return None
    if n < 3:
        return 1
    return fib2(n - 1) + fib2(n - 2)

for n in range(1, 10):  # testing
    print(n, "->", fib2(n))
# Out:
# 1 -> 1
# 2 -> 1
# 3 -> 2
# 4 -> 3
# 5 -> 5
# 6 -> 8
# 7 -> 13
# 8 -> 21
# 9 -> 34

# %% [markdown]
# # Factorial V1

# %%
def factorial_function(n):
    if n < 0:
        return None
    if n < 2:
        return 1
    
    product = 1
    for i in range(2, n + 1):
        product *= i
    return product


for n in range(1, 6):  # testing
    print(n, factorial_function(n))
# Out:
# 1 1
# 2 2
# 3 6
# 4 24
# 5 120

# %%
def factorial_function(n):
    if n < 0:
        return None
    if n < 2:
        return 1
    return n * factorial_function(n - 1)

# %%
factorial_function(-5)

# %%
# Recursive implementation of the factorial function.

def factorial(n):
    if n == 1:    # The base case (termination condition.)
        return 1
    else:
        return n * factorial(n - 1)


print(factorial(-5)) # 4 * 3 * 2 * 1 = 24
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-17-6171c384f2ed> in <module>()
#       8
#       9
# ---> 10 print(factorial(-5)) # 4 * 3 * 2 * 1 = 24
#      11
#
# <ipython-input-17-6171c384f2ed> in factorial(n)
#       5         return 1
#       6     else:
# ----> 7         return n * factorial(n - 1)
#       8
#       9
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-17-6171c384f2ed> in factorial(n)
#       5         return 1
#       6     else:
# ----> 7         return n * factorial(n - 1)
#       8
#       9
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
def factorial(n):
    return n * factorial(n - 1)


print(factorial(4))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-18-9d7996b76d6d> in <module>()
#       3
#       4
# ----> 5 print(factorial(4))
#
# <ipython-input-18-9d7996b76d6d> in factorial(n)
#       1 def factorial(n):
# ----> 2     return n * factorial(n - 1)
#       3
#       4
#       5 print(factorial(4))
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-18-9d7996b76d6d> in factorial(n)
#       1 def factorial(n):
# ----> 2     return n * factorial(n - 1)
#       3
#       4
#       5 print(factorial(4))
#
# RecursionError: maximum recursion depth exceeded

# %%
def fun(a):
    if a > 30:
        return 3
    else:
        return a + fun(a + 3)


print(fun(25))
# Out:
# 56

# %%
25 + 28 + 3
# Out:
# 56

# %%
a = [3,2,1]
a[2] = 5
a
# Out:
# [3, 2, 5]

# %%
b = (3,2,1)
b[0] = 5
b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f1747240de9c> in <module>()
#       1 b = (3,2,1)
# ----> 2 b[0] = 5
#       3 b
#
# TypeError: 'tuple' object does not support item assignment

# %%
b[0]
# Out:
# 3

# %%
a = ('a',2,-4,0.5)

# %%
a[0]
# Out:
# 'a'

# %%
a = [3,2,1]
a
del a[2]
a
# Out:
# [3, 2]

# %%
b = (3,2,1)
b
del b[2]
b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-0cec7049d78f> in <module>()
#       1 b = (3,2,1)
#       2 b
# ----> 3 del b[2]
#       4 b
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
del b

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-89e6c98d9288> in <module>()
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
tuple_kosong = ()
tuple_kosong = (1,)

# %%
tuple_kosong
# Out:
# (1,)

# %%
my_tuple = (1, 10, 100, 1000)

print(my_tuple[0])
print(my_tuple[-1])
# Out:
# 1
# 1000

# %%
print(my_tuple[1:])
print(my_tuple[:-2])
# Out:
# (10, 100, 1000)
# (1, 10)

# %%
for elem in my_tuple:
    print(elem)
# Out:
# 1
# 10
# 100
# 1000

# %%
my_tuple = (1, 10, 100, 1000)

my_tuple.append(10000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-3a3a76c7fab3> in <module>()
#       1 my_tuple = (1, 10, 100, 1000)
#       2
# ----> 3 my_tuple.append(10000)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
del my_tuple[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-ca3904289ce8> in <module>()
# ----> 1 del my_tuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
my_tuple[1] = -10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-8c45685aa050> in <module>()
# ----> 1 my_tuple[1] = -10
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple = (1, 10, 100)

t1 = my_tuple + (1000, 10000)
t2 = my_tuple * 3

print(len(t2))
# Out:
# 9

# %%
t2
# Out:
# (1, 10, 100, 1, 10, 100, 1, 10, 100)

# %%
print(t1)
# Out:
# (1, 10, 100, 1000, 10000)

# %%
print(t2)
# Out:
# (1, 10, 100, 1, 10, 100, 1, 10, 100)

# %%
print(10 in my_tuple)
# Out:
# True

# %%
print(-10 not in my_tuple)
# Out:
# True

# %%
var = 123

t1 = [1, ]
t2 = [2, ]
t3 = [3, var]

t1, t2, t3 = t2, t3, t1

print(t1, t2, t3)
# Out:
# [2] [3, 123] [1]

# %%
var = 123

t1 = (1, )
t2 = (2, )
t3 = (3, var)

t1, t2, t3 = t2, t3, t1

print(t1, t2, t3)
# Out:
# (2,) (3, 123) (1,)

# %% [markdown]
# # Dictionary

# %%
dictionary = {"cat": "chat", "dog": "chien", "horse": "cheval"}
phone_numbers = {'boss': 5551234567, 'Suzy': 22657854310}
empty_dictionary = {}

print(dictionary)
print(phone_numbers)
print(empty_dictionary)
# Out:
# {'cat': 'chat', 'dog': 'chien', 'horse': 'cheval'}
# {'boss': 5551234567, 'Suzy': 22657854310}
# {}

# %%
var = {'a':123, 'b':456}

# %%
print(var)
# Out:
# {'a': 123, 'b': 456}

# %%
print(var['a'])
# Out:
# 123

# %%
dictionary['Horse']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-109ea20807ea> in <module>()
# ----> 1 dictionary['Horse']
#
# KeyError: 'Horse'

# %%
dictionary['fish']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-5649ba1b0ec1> in <module>()
# ----> 1 dictionary['fish']
#
# KeyError: 'fish'

# %%
dictionary = {"cat": "chat", "dog": "chien", "horse": "cheval"}
words = ['cat', 'lion', 'horse']

for word in words:
    if word in dictionary:
        print(word, "->", dictionary[word])
    else:
        print(word, "is not in dictionary")
# Out:
# cat -> chat
# lion is not in dictionary
# horse -> cheval

# %%
dictionary = {
               "cat": "chat", 
               "dog": "chien", 
               "horse": "cheval"
             }

# %%
dictionary['dog']
# Out:
# 'chien'

# %%
dictionary.keys()
# Out:
# dict_keys(['cat', 'dog', 'horse'])

# %%
dictionary = {"cat": "chat", "dog": "chien", "horse": "cheval"}

for key in dictionary.keys():
    print(key, "->", dictionary[key])
# Out:
# cat -> chat
# dog -> chien
# horse -> cheval

# %%
kamus = {"B": "makan", "C": "tidur","A":"Minum"}
kamus
# Out:
# {'A': 'Minum', 'B': 'makan', 'C': 'tidur'}

# %%
kamus.keys()
# Out:
# dict_keys(['B', 'C', 'A'])

# %%
kamus['B']
# Out:
# 'makan'

# %%
urut = sorted(kamus.keys())

# %%
urut.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-def614736cbf> in <module>()
# ----> 1 urut.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
urut2 =sorted(kamus)

# %%
urut2
# Out:
# ['A', 'B', 'C']

# %%
urut2.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-98f8271e95a0> in <module>()
# ----> 1 urut2.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
dictionary = {"cat": "chat", "dog": "chien", "horse": "cheval"}

for key in dictionary.keys():
    print(key, "->", dictionary[key])
# Out:
# cat -> chat
# dog -> chien
# horse -> cheval

# %%
dictionary.keys()
# Out:
# dict_keys(['cat', 'dog', 'horse'])

# %%
dictionary.items()
# Out:
# dict_items([('cat', 'chat'), ('dog', 'chien'), ('horse', 'cheval')])

# %%
dictionary.values()
# Out:
# dict_values(['chat', 'chien', 'cheval'])

# %%
dictionary
# Out:
# {'cat': 'chat', 'dog': 'chien', 'horse': 'cheval'}

# %%
dictionary = {"cat": "chat", "dog": "chien", "horse": "cheval"}

for item in dictionary.values():
    print(item)
# Out:
# chat
# chien
# cheval

# %%
dictionary = {"cat": "chat", "dog": "chien", "horse": "cheval"}

print(dictionary)
# Out:
# {'cat': 'chat', 'dog': 'chien', 'horse': 'cheval'}

# %%
dictionary['cat'] = 'minou'
print(dictionary)
# Out:
# {'cat': 'minou', 'dog': 'chien', 'horse': 'cheval'}

# %%
dictionary['swan'] = 'angsa'
print(dictionary)
# Out:
# {'cat': 'minou', 'dog': 'chien', 'horse': 'cheval', 'swan': 'angsa'}

# %%
del dictionary['cat']
print(dictionary)
# Out:
# {'dog': 'chien', 'horse': 'cheval', 'swan': 'angsa'}

# %%
del dictionary['bird']
print(dictionary)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-ce22331e8cd6> in <module>()
# ----> 1 del dictionary['bird']
#       2 print(dictionary)
#
# KeyError: 'bird'

# %%
school_class = {}

while True:
    name = input("Enter the student's name: ")
    if name == '':
        break
    
    score = int(input("Enter the student's score (0-10): "))
    if score not in range(0, 11):
	    break
    
    if name in school_class:
        school_class[name] += (score,)
    else:
        school_class[name] = (score,)
        
for name in sorted(school_class.keys()):
    adding = 0
    counter = 0
    for score in school_class[name]:
        adding += score
        counter += 1
    print(name, ":", adding / counter)
# Out:
# Enter the student's name: alzami
# Enter the student's score (0-10): 9
# Enter the student's name: tiara
# Enter the student's score (0-10): 7
# Enter the student's name: kiki
# Enter the student's score (0-10): 8
# Enter the student's name: alzami
# Enter the student's score (0-10): 6
# Enter the student's name: kiki
# Enter the student's score (0-10): 9
# Enter the student's name:
# alzami : 7.5
# kiki : 8.5
# tiara : 7.0

# %%
school_class
# Out:
# {'alzami': (9, 6), 'kiki': (8, 9), 'tiara': (7,)}

# %%
sekolah = {}

# %%
sekolah = {'alzami': (8)}
sekolah = {'alzami': (7)}

# %%
sekolah
# Out:
# {'alzami': 7}

# %%
sekolah = sekolah + {'alzami': (4)}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-645ffe37fd72> in <module>()
# ----> 1 sekolah = sekolah + {'alzami': (4)}
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
nama = 'satu',
nama
# Out:
# ('satu',)

# %%
lists = ['alzami','pramunendar','supriyanto']
type(lists)
# Out:
# list

# %%
lists
# Out:
# ['alzami', 'pramunendar', 'supriyanto']

# %%
menjadiTuple = tuple(lists)

# %%
type(menjadiTuple)
# Out:
# tuple

# %%
menjadiTuple
# Out:
# ('alzami', 'pramunendar', 'supriyanto')

# %%
my_dictionary = {
    'key1': 'value1',
    'key2': 'value2',
    'key3': 'value3',
    }

# %%
my_dictionary
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %%
my_dictionary['key1'] = "value_x"

# %%
my_dictionary
# Out:
# {'key1': 'value_x', 'key2': 'value2', 'key3': 'value3'}

# %%
pol_eng_dictionary = {
    "zamek": "castle",
    "woda": "water",
    "gleba": "soil"
    }

copy_dictionary = pol_eng_dictionary.copy()

# %%
pol_eng_dictionary['zamek'] = 'istana'

# %%
pol_eng_dictionary
# Out:
# {'gleba': 'soil', 'woda': 'water', 'zamek': 'istana'}

# %%
copy_dictionary
# Out:
# {'gleba': 'soil', 'woda': 'water', 'zamek': 'castle'}

# %%
lists2 = [1,2,3,4,5,4]

# %%
dup = lists2.count(4)

# %%
dup
# Out:
# 2

# %%
d1 = {'Adam Smith': 'A', 'Judy Paxton': 'B+'}
d2 = {'Mary Louis': 'A', 'Patrick White': 'C'}
d3 = {}

for item in (d1, d2):
    d3.update(item)

print(d3)
# Out:
# {'Adam Smith': 'A', 'Judy Paxton': 'B+', 'Mary Louis': 'A', 'Patrick White': 'C'}

# %% [markdown]
# # Exception

# %%
value = int(input('Enter a natural number: '))
print('The reciprocal of', value, 'is', 1/value)
# Out:
# Enter a natural number: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-132-9695afba8f6b> in <module>()
#       1 value = int(input('Enter a natural number: '))
# ----> 2 print('The reciprocal of', value, 'is', 1/value)
#
# ZeroDivisionError: division by zero

# %%
try:
    value = int(input('Enter a natural number: '))
    print('The reciprocal of', value, 'is', 1/value)        
except:
    print('maaf saya yang salah')
# Out:
# Enter a natural number: 3.5
# maaf saya yang salah

# %%
try:
    value = int(input('Enter a natural number: '))
    print('The reciprocal of', value, 'is', 1/value)        
except ZeroDivisionError:
    print('maaf saya tidak tahu kalau tidak boleh angka 0')
except ValueError:
    print('maaf saya tidak tahu kalau tidak boleh selain integer')
# Out:
# Enter a natural number: a
# maaf saya tidak tahu kalau tidak boleh selain integer

# %%
try:
    value = int(input('Enter a natural number: '))
    print('The reciprocal of', value, 'is', 1/value)        
except ZeroDivisionError:
    print('maaf saya tidak tahu kalau tidak boleh angka 0')
except ValueError:
    print('maaf saya tidak tahu kalau tidak boleh selain integer') 
except:
    print('Something strange has happened here... Sorry!')
# Out:
# Enter a natural number: !
# maaf saya tidak tahu kalau tidak boleh selain integer

# %%
short_list = [1]
one_value = short_list[0.5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-a3508f78dd15> in <module>()
#       1 short_list = [1]
# ----> 2 one_value = short_list[0.5]
#
# TypeError: list indices must be integers or slices, not float

# %%
one_value
# Out:
# 1

# %%
short_list = [1]
short_list.append(2)
short_list.depend(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-c9bb9e8098d8> in <module>()
#       1 short_list = [1]
#       2 short_list.append(2)
# ----> 3 short_list.depend(3)
#
# AttributeError: 'list' object has no attribute 'depend'

# %%
temperature = float(input('Enter current temperature:'))

if temperature > 0:
    print("Above zero")
elif temperature < 0:
    prin("Below zero")
else:
    print("Zero")
# Out:
# Enter current temperature:-3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-e4822ae93172> in <module>()
#       4     print("Above zero")
#       5 elif temperature < 0:
# ----> 6     prin("Below zero")
#       7 else:
#       8     print("Zero")
#
# NameError: name 'prin' is not defined

# %%
def fun(masuk=2, keluar = 3):
  return masuk * keluar

print(fun(5))
# Out:
# 15
