# %%
2+3*5
# Out:
# 17

# %%
2 + 6 / 2
# Out:
# 5.0

# %%
9%6
# Out:
# 3

# %%
3%2
# Out:
# 1

# %%
print(9 % 6 % 2)
# Out:
# 1

# %%
print((9 % 6) % 2)
# Out:
# 1

# %%
print(2 ** 2 ** 3)
# Out:
# 256

# %%
print((2 ** 2) ** 3)
# Out:
# 64

# %%
print(2 ** (2 ** 3))
# Out:
# 256

# %%
print( 9 % 6 ** 2)
# Out:
# 9

# %%
print(9**2 % 3)
# Out:
# 0

# %%
print(5 * 25 % 13 + 100 / 2 * 13 // 2)
# Out:
# 333.0

# %%
print((5 * ((25 % 13) + 100) / (2 * 13)) // 2)
# Out:
# 10.0

# %% [markdown]
# variabel

# %%
a = 3

# %%
a = 3

# %% [markdown]
# class = Class
#
# var = var_01
#
# fungsi = fun_simpanPegawai

# %%
A = 1
a = 2

# %%
a
# Out:
# 2

# %%
A
# Out:
# 1

# %%
# Out:
#   File "<ipython-input-28-15b4f483ee6c>", line 1
#     break = 2
#           ^
# SyntaxError: invalid syntax

# %%
while  = 2
# Out:
#   File "<ipython-input-29-9c178f41991d>", line 1
#     while  = 2
#            ^
# SyntaxError: invalid syntax

# %%
While = 2

# %%
var = 15
print(Var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-8dbd10924b00> in <module>()
#       1 var = 15
# ----> 2 print(Var)
#
# NameError: name 'Var' is not defined

# %% [markdown]
# bentuk-bentuk lain

# %%
a = 20
print('ayam saya bertelur '+ a + 'biji hari ini')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-d5c7688ed1c3> in <module>()
#       1 a = 20
# ----> 2 print('ayam saya bertelur '+ a + 'biji hari ini')
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('ayam saya bertelur '+ str(a) + ' biji hari ini')
# Out:
# ayam saya bertelur 20biji hari ini

# %%
b = '20'
print('ayam saya bertelur '+ b + ' biji hari ini')
# Out:
# ayam saya bertelur 20 biji hari ini

# %%
c = 20
print('ayam saya bertelur %d biji hari ini' % (c))
# Out:
# ayam saya bertelur 20 biji hari ini

# %%
var = 1
print(var)
var = var + 1
print(var)
# Out:
# 1
# 2

# %% [markdown]
# studi kasus:
#
# Once upon a time in Appleland,
#
# John had three apples,
#
# Mary had five apples,
#
# and Adam had six apples.
#
# They were all very happy and lived for a long time. End of story.

# %%
john = 3
mary = 5
adam = 6

# %%
print(john,mary,adam)
# Out:
# 3 5 6

# %%
total_apples = john + mary + adam

# %%
print(total_apples)
# Out:
# 14

# %%
print('maka total apple yang dipunyai adalah ', total_apples)
# Out:
# maka total apple yang dipunyai adalah  14

# %%
print('john mempunyai ', john, ' apel, lalu mary mempunyai ', mary, ' apel, dan adam mempunyai ',adam)
# Out:
# john mempunyai  3  apel, lalu mary mempunyai  5  apel, dan adam mempunyai  6

# %% [markdown]
# shortcut

# %%
x = 5

# %%
x = x * 2

# %%
x
# Out:
# 5

# %%
x *= 2

# %%
x
# Out:
# 10

# %%
y = 3
y = y + 5

# %%
y
# Out:
# 8

# %%
y += 5

# %%
y
# Out:
# 13

# %%
a = '2'
b = '3'
print(a+b)
# Out:
# 23

# %%
print(a*b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-f9c8a447c001> in <module>()
# ----> 1 print(a*b)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-b0b33af54914> in <module>()
# ----> 1 print(a/b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
print(a+b*2)
# Out:
# 233

# %%
# a = 3
# b = 6

# %%
"""
  ini adalah pengenalan bahasa python
  var a adalah int
"""
# Out:
# '\n  ini adalah pengenalan bahasa python\n  var a adalah int\n'

# %% [markdown]
# inputan

# %%
print('masukkan nama anda')
nama = input()
print('selamat datang ',nama)
# Out:
# masukkan nama anda
# farrikh
# selamat datang  farrikh

# %%
alamat = input('masukkan alamat anda: ')
print(alamat)
# Out:
# masukkan alamat anda: beringin
# beringin

# %%
anything = input("Enter a number: ")
# Out:
# Enter a number: 3

# %%
print(type(anything))
# Out:
# <class 'str'>

# %%
something = anything ** 2.0
print(anything, "to the power of 2 is", something)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-5ff544a898f4> in <module>()
# ----> 1 something = anything ** 2.0
#       2 print(anything, "to the power of 2 is", something)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'float'

# %%
something = float(anything) ** 2.0
print(anything, "to the power of 2 is", something)
# Out:
# 3 to the power of 2 is 9.0

# %%
anything = float(input("Enter a number: "))
something = anything ** 2.0
print(anything, "to the power of 2 is", something)
# Out:
# Enter a number: 3
# 3.0 to the power of 2 is 9.0
