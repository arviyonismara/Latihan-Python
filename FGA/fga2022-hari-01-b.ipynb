# %%
print('selamat datang di hari kedua materi pelatihan python')
# Out:
# selamat datang di hari kedua materi pelatihan python

# %%
print('ini hari jumat, jadi ini weekday terakhir')
# Out:
# ini hari jumat, jadi ini weekday terakhir
