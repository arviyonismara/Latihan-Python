# %% [markdown]
# # Pendahuluan

# %% [markdown]
# ## Pengenalan Python

# %%
print('selamat datang di FGA Cisco Python Big Data')
# Out:
# selamat datang di FGA Cisco Python Big Data

# %% [markdown]
# ### cara pemanggilan yang salah

# %%
print 'selamat datang di FGA'
# Out:
#   File "<ipython-input-3-0ce2699619c2>", line 1
#     print 'selamat datang di FGA'
#                                 ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('selamat datang di FGA')?

# %%
print(selamat datang di FGA)
# Out:
#   File "<ipython-input-4-03f2e3d4c94d>", line 1
#     print(selamat datang di FGA)
#                        ^
# SyntaxError: invalid syntax

# %%
prin('saya tidak bisa cetak')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e827b377be88> in <module>()
# ----> 1 prin('saya tidak bisa cetak')
#
# NameError: name 'prin' is not defined

# %%
kata = 'selamat datang di pelatihan cisco big data with python di hari jumat'
print(kata)
# Out:
# selamat datang di pelatihan cisco big data with python di hari jumat
