# %% [markdown]
# # Pengenalan Python hari 02 (review)
#
# Farrikh Alzami
#
# - belajar matematika
#   - belajar tentang angka
#   - belajar tentang aritmatika
# - kesimpulan

# %% [markdown]
# ## belajar matematika - tentang angka

# %% [markdown]
# ### aritmatika dasar - penjumlahan

# %%
4 + 2
# Out:
# 6

# %%
a = 3
b = 7

# %%
c = a + b

# %%
c
# Out:
# 10

# %%
print(c)
# Out:
# 10

# %%
print(a+b)
# Out:
# 10

# %% [markdown]
# ### pengurangan

# %%
d = a-b
print(d)
# Out:
# -4

# %% [markdown]
# ### perkalian

# %%
e = a*b
print(e)
# Out:
# 21

# %% [markdown]
# ### pembagian

# %%
f = a/b
print(f)
# Out:
# 0.42857142857142855

# %% [markdown]
# ### pembagian floor

# %%
g = b//a
print(g)
# Out:
# 2

# %% [markdown]
# ## modulo

# %%
h = b % a
print(h)
# Out:
# 1

# %% [markdown]
# ### pangkat

# %%
i = b ** a
print(i)
# Out:
# 343

# %% [markdown]
# ### akar

# %%
j = 4 ** 0.5
print(j)
# Out:
# 2.0

# %% [markdown]
# ### urutan operasi pada python

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
2 + (10*10) + 3
# Out:
# 105

# %%
(2 + 10) * (10+3)
# Out:
# 156

# %%
print(a)
# Out:
# 3

# %% [markdown]
# ### reassign nilai variabel

# %%
a = 9
print(a)
# Out:
# 9

# %%
print(b)
# Out:
# 7

# %%
b = b + b

# %%
print(b)
# Out:
# 14

# %% [markdown]
# ## pembuatan variabel

# %%
var_01 = 3

# %%
01_var = 7
# Out:
#   File "<ipython-input-23-02d06b98b448>", line 1
#     01_var = 7
#       ^
# SyntaxError: invalid token

# %%
var_02 = 3.5

# %%
var_03 = selamat

# %%
var_03 = 'selamat datang '

# %% [markdown]
# ## tipe variabel

# %%
type(var_01)

# %%
type(var_02)

# %%
type(var_03)

# %%
tambah = var_01 + var_02
print(tambah)
type(tambah)

# %%
kurang  = var_01 - var_02
print(kurang)
type(kurang)

# %%
kurang2 = 2-3
print(kurang2)
type(kurang2)

# %%
tambah_str = var_01 + var_03
print(tambah_str)

# %%
tambah_str2 = 4 + 'selamat'
print(tambah_str2)

# %%
perkalian_str = var_01 * var_03
print(perkalian_str)

# %%
perkalian_str2 = var_03 * var_01
print(perkalian_str2)

# %%
kurang_str = var_01 - var_03
print(kurang_str)

# %%
bagi_str = var_01 / var_03
print(bagi_str)

# %% [markdown]
# ## penulisan komplet

# %%
a = 3
b = 2
c = a + b
print('hasil penambahan dari %d dengan %d adalah %d' % (a,b,c))
d = a * b
print('hasil perkalian dari %d dengan %d adalah %d' % (a,b,d))
