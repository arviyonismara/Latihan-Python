# %%
char_1 = 'a'
char_2 = ' '  # space

print(ord(char_1)) # ord() untuk mengetahui ordinal/ code dari sebuah karakter
print(ord(char_2))

# Demonstrating the chr() function.

print(chr(97))
print(chr(945))
# Out:
# 97
# 32
# a
# α

# %%
chr(ord('x')) == 'x'
# Out:
# True

# %%
ord(chr(97)) == 'x'
# Out:
# False

# %% [markdown]
# # indexing

# %%
karakter = 'ABC'
karakter[0]
# Out:
# 'A'

# %%
# Indexing strings.

the_string = 'silly walks'

for ix in range(len(the_string)):
    print(the_string[ix], end=' ')

print()
# Out:
# s i l l y   w a l k s

# %%
# Iterating through a string.

the_string = 'silly walks'

for character in the_string:
    print(character, end=' ')

print()
# Out:
# s i l l y   w a l k s

# %%
kata = 'kominfo'
print(kata[1:])# ini artinya dimulai dari index [1] sampai terakhir
# Out:
# ominfo

# %%
print(kata[1:4]) # ini artinya dari index [1] sampai index ke [3]
# Out:
# omi

# %%
print(kata[:4]) # ini artinya dari index [3] sampai index [0]
# Out:
# komi

# %%
print(kata[:-2]) # ini artinya dari index ketiga dari terakhir
# Out:
# komin

# %%
print(kata[3:-2]) # ini artinya diantara index ketiga terakhir [-2] dan index ke [3]
# Out:
# in

# %%
print(kata[::2]) # hanya print index kelipatan 2 / split step
# Out:
# kmno

# %%
print(kata[1::2]) # ini artinya print mulai dari index [1] kemudian lompat satu step
# Out:
# oif

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"

print("f" in alphabet)
print("F" in alphabet)
print("1" in alphabet)
print("ghi" in alphabet)
print("Xyz" in alphabet)
print("ace" in alphabet)
#untuk mengetahui keberadaan suatu elemen di sebuah variable
# Out:
# True
# False
# False
# True
# False
# False

# %%
alphabet[2]
# Out:
# 'c'

# %%
del alphabet[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-2793eb93dcea> in <module>()
# ----> 1 del alphabet[2]
#
# TypeError: 'str' object doesn't support item deletion

# %%
del alphabet

# %%
alphabet = "bcdefghijklmnopqrstuvwxy"

alphabet = "a" + alphabet
alphabet = alphabet + "z"

print(alphabet)
# Out:
# abcdefghijklmnopqrstuvwxyz

# %%
# Demonstrating min() - Example 1:
print(min("aAbByYzZ"))
# Out:
# A

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
# Demonstrating min() - Example 1:
print(max("aAbByYzZ"))
# Out:
# z

# %%
ord('z')
# Out:
# 122

# %%
ord(' ')
# Out:
# 32

# %%
ord("\'")
# Out:
# 39

# %%
ord("\"")
# Out:
# 34

# %%
ord("!")
# Out:
# 33

# %%
# Demonstrating min() - Examples 2 & 3:
t = 'The Knights Who Say "Ni!"'
print('[' + min(t) + ']')
# Out:
# [ ]

# %%
# Demonstrating the index() method:
print("aAbByYzZaA".index("b"))
# Out:
# 2

# %%
# Demonstrating the index() method:
print("aAbByYzZaA".index("a"))
# Out:
# 0

# %%
# Demonstrating the list() function:
print(list("abcabc"))
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c']

# %%
list("1,2,3")
# Out:
# ['1', ',', '2', ',', '3']

# %%
print("abcabc".count("b"))
# Out:
# 2

# %%
print('abcabc'.count("d"))
# Out:
# 0

# %%
paragraf = '''
              saya makan nasi padang,
              enak sekali
              pakai telur
           '''

# %%
paragraf
# Out:
# '\n              saya makan nasi padang,\n              enak sekali\n              pakai telur\n           '

# %% [markdown]
# #capitalize

# %%
print("Alpha".capitalize())
print('ALPHA'.capitalize())
print(' Alpha'.capitalize())
print('123'.capitalize())
print("αβγδ".capitalize())
# Out:
# Alpha
# Alpha
#  alpha
# 123
# Αβγδ

# %%
print("saya suka makan nasi padang".capitalize())
# Out:
# Saya suka makan nasi padang

# %%
print("saya suka makan nasi padang".upper())
# Out:
# SAYA SUKA MAKAN NASI PADANG

# %% [markdown]
# #center

# %%
# Demonstrating the center() method:
print('[' + 'cisco' + ']')
# Out:
# [cisco]

# %%
# Demonstrating the center() method:
print('[' + 'cisco'.center(10) + ']')
# Out:
# [  cisco   ]

# %%
# Demonstrating the center() method:
print('[' + 'cisco'.center(20) + ']')
# Out:
# [       cisco        ]

# %%
print('[' + 'gamma'.center(20, '*') + ']')
# Out:
# [*******gamma********]

# %% [markdown]
# #endwith()

# %%
t = "zeta"
print(t.endswith("a"))
print(t.endswith("A"))
print(t.endswith("et"))
print(t.endswith("eta"))
print(t.endswith("zeta"))
# Out:
# True
# False
# False
# True
# True

# %%
# Demonstrating the find() method:
print("Eta".find("ta"))
print("Eta".find("E"))
print("Eta".find("te"))
print("Eta".find("mma"))
# Out:
# 1
# 0
# -1
# -1

# %% [markdown]
# # isalnum

# %%
# Demonstrating the isalnum() method:
print('lambda30'.isalnum())
print('lambda'.isalnum())
print('30'.isalnum())
print('@'.isalnum())
print('lambda_30'.isalnum())
print('lambda 30'.isalnum())
print(''.isalnum())
# Out:
# True
# True
# True
# False
# False
# False
# False

# %%
t = 'Six lambdas'
print(t.isalnum())

t = 'ΑβΓδ'
print(t.isalnum())

t = '20E1'
print(t.isalnum())
# Out:
# False
# True
# True

# %% [markdown]
# #isalpha

# %%
# Example 1: Demonstrating the isapha() method:
print("Moooo".isalpha())
print('Mu40'.isalpha())
print("moooo".isalpha())

# Example 2: Demonstrating the isdigit() method:
print('2018'.isdigit())
print("Year2019".isdigit())
# Out:
# True
# False
# True
# True
# False

# %%
# Example 1: Demonstrating the islower() method:
print("Moooo".islower())
print('moooo'.islower())
# Out:
# False
# True

# %%
# Example 2: Demonstrating the isspace() method:
print(' \n '.isspace())
print(" ".isspace())
print("mooo mooo mooo".isspace())
# Out:
# True
# True
# False

# %%
# Example 3: Demonstrating the isupper() method:
print("Moooo".isupper())
print('moooo'.isupper())
print('MOOOO'.isupper())
# Out:
# False
# False
# True

# %%
# Demonstrating the join() method:
print("&".join(["omicron", "pi", "rho"]))
# Out:
# omicron&pi&rho

# %%
# Demonstrating the lower() method:
print("SiGmA=60".lower())
# Out:
# sigma=60

# %% [markdown]
# #lstrip

# %%
# Demonstrating the lstrip() method:
print("[" + " tau ".lstrip() + "]")
# Out:
# [tau ]

# %%
var1 =' saya makan nasi '
print(var1)
print(var1.lstrip())
# Out:
#  saya makan nasi
# saya makan nasi

# %%
var1 =' saya makan nasi '
print(var1)
print(var1.rstrip())
# Out:
#  saya makan nasi
#  saya makan nasi

# %%
print("www.cisco.com".lstrip("w."))
# Out:
# cisco.com

# %%
print("www.cisco.com".lstrip("w"))
# Out:
# .cisco.com

# %%
print("wab.cisco.com".lstrip("w."))
# Out:
# ab.cisco.com

# %%
print("waw.cisco.com".lstrip("w."))
# Out:
# aw.cisco.com

# %%
print("pythoninstitute.org".lstrip(".org"))
# Out:
# pythoninstitute.org

# %%
print("pythoninstitute.org".rstrip(".org"))
# Out:
# pythoninstitute

# %% [markdown]
# # replace

# %%
# Demonstrating the replace() method:
print("www.netacad.com".replace("netacad.com", "pythoninstitute.org"))
print("This is it!".replace("is", "are"))
print("Apple juice".replace("juice", ""))
# Out:
# www.pythoninstitute.org
# Thare are it!
# Apple

# %%
print("This is it!".replace("is", "are", 1))
print("This is it!".replace("is", "are", 2))
# Out:
# Thare is it!
# Thare are it!

# %%
print('saya sangat suka sari rasa'.replace('sa','si'))
# Out:
# siya singat suka siri rasi

# %%
print('saya sangat suka sari rasa'.replace('sa','si',1))
# Out:
# siya sangat suka sari rasa

# %%
print('saya sangat suka sari rasa'.replace('sa','si',0))
# Out:
# saya sangat suka sari rasa

# %%
print('saya sangat suka sari rasa'.replace('sa','si',4))
# Out:
# siya singat suka siri rasi

# %%
print('saya sangat suka sari rasa'.replace('sa','si',5))
# Out:
# siya singat suka siri rasi

# %% [markdown]
# #rfind

# %%
print('tau'.rfind('ta'))
# Out:
# 0

# %%
print('tau tau'.rfind('ta'))
# Out:
# 4

# %%
print('tau tau'.rfind('ta',6))
# Out:
# -1

# %%
print('tau tau'.rfind('ta',0,7))
# Out:
# 4

# %%
# Demonstrating the rfind() method:
print("tau tau tau".rfind("ta"))
print("tau tau tau".rfind("ta", 9))
print("tau tau tau".rfind("ta", 3, 9))
# Out:
# 8
# -1
# 4

# %%
# Demonstrating the rstrip() method:
print("[" + " upsilon ".rstrip() + "]")
print("cisco.com".rstrip(".com"))
# Out:
# [ upsilon]
# cis

# %%
# Demonstrating the split() method:
print("phi       chi\npsi")
# Out:
# phi       chi
# psi

# %%
# Demonstrating the split() method:
print("phi       chi\npsi".split())
# Out:
# ['phi', 'chi', 'psi']

# %% [markdown]
# #startwith

# %%
# Demonstrating the startswith() method:
print("omega".startswith("meg"))
print("omega".startswith("om"))

print()

# Demonstrating the strip() method:
print("[" + "   aleph   ".strip() + "]")
# Out:
# False
# True
#
# [aleph]

# %%
print('Saya Suka Makan Nasi Padang'.swapcase())
# Out:
# sAYA sUKA mAKAN nASI pADANG

# %%
print('Angkatan123'.swapcase())
# Out:
# aNGKATAN123

# %%
print('materi pelatihan FGA big data'.title())
# Out:
# Materi Pelatihan Fga Big Data

# %%
s1 = 'Where are the snows of yesteryear?'
s2 = s1.split()
s2
# Out:
# ['Where', 'are', 'the', 'snows', 'of', 'yesteryear?']

# %% [markdown]
# #soal PR

# %%
kotak = []
kotak.append('a')
kotak
# Out:
# ['a']

# %%
a = ' '
a.isspace()
# Out:
# True

# %%
def mysplit(strng):
  kotak2 = []
  for chr in strng:
    if chr.isspace() == True:
      continue  
    kotak2.append(chr)
  return kotak2

# %%
print("To be or not to be, that is the question".split())
# Out:
# ['To', 'be', 'or', 'not', 'to', 'be,', 'that', 'is', 'the', 'question']

# %%
print(mysplit("To be or not to be, that is the question"))
# Out:
# ['T', 'o', 'b', 'e', 'o', 'r', 'n', 'o', 't', 't', 'o', 'b', 'e', ',', 't', 'h', 'a', 't', 'i', 's', 't', 'h', 'e', 'q', 'u', 'e', 's', 't', 'i', 'o', 'n']

# %%
'alpha' < 'alphabet'
# Out:
# True

# %%
'alpha' < 'alphab'
# Out:
# True

# %%
'alpha' < 'alpha'
# Out:
# False

# %%
'alpha' < 'Alpha'
# Out:
# False

# %%
'10' == '010'
# Out:
# False

# %%
'10' > '010'
# Out:
# True

# %%
'10' > '8'
# Out:
# False

# %%
ord('1')
# Out:
# 49

# %%
ord('8')
# Out:
# 56

# %%
'20' < '8'
# Out:
# True

# %%
itg = 13
flt = 1.3

# %%
type(itg)
# Out:
# int

# %%
itgs = str(itg)
type(itgs)
# Out:
# str

# %%
si = '13'
sf = '1.3'
itg = int(si)
flt = float(sf)

print(itg + flt)
# Out:
# 14.3

# %%
sf = '1.3'
type(sf)
sf2 = float(sf)
sf2
type(sf2)
# Out:
# float

# %%
sf2
# Out:
# 1.3

# %%
'huruf' >= 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\00-template\python\Latihan Pyton\FGA\FGA Hari 11.ipynb Cell 115 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/00-template/python/Latihan%20Pyton/FGA/FGA%20Hari%2011.ipynb#Y222sZmlsZQ%3D%3D?line=0'>1</a> 'huruf' >= 3
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
3 >= 'satu'
# Out:
# Running cells with 'Python 3.9.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ACER/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #cipher

# %%
# Caesar cipher.
text = input("Enter your message: ")
cipher = ''
for char in text:
    if not char.isalpha():
        continue
    char = char.upper()
    code = ord(char) + 1
    if code > ord('Z'):
        code = ord('A')
    cipher += chr(code)

print(cipher)

# %%
# Caesar cipher - decrypting a message.
cipher = input('Enter your cryptogram: ')
text = ''
for char in cipher:
    if not char.isalpha():
        continue
    char = char.upper()
    code = ord(char) - 1
    if code < ord('A'):
        code = ord('Z')
    text += chr(code)

print(text)

# %%
# Numbers Processor.

line = input("Enter a line of numbers - separate them with spaces: ")
strings = line.split()
total = 0
try:
    for substr in strings:
        total += float(substr)
    print("The total is:", total)
except:
    print(substr, "is not a number.")
# Out:
# awda is not a number.

# %%
# IBAN Validator.

iban = input("Enter IBAN, please: ")
iban = iban.replace(' ','')

if not iban.isalnum():
    print("You have entered invalid characters.")
elif len(iban) < 15:
    print("IBAN entered is too short.")
elif len(iban) > 31:
    print("IBAN entered is too long.")
else:
    iban = (iban[4:] + iban[0:4]).upper()
    iban2 = ''
    for ch in iban:
        if ch.isdigit():
            iban2 += ch
        else:
            iban2 += str(10 + ord(ch) - ord('A'))
    iban = int(iban2)
    if iban % 97 == 1:
        print("IBAN entered is valid.")
    else:
        print("IBAN entered is invalid.")
# Out:
# IBAN entered is too short.

# %%
# Caesar cipher.
text = input("Enter your message: ")
geser = int(input('mau geser berapa'))
cipher = ''
for char in text:
    if not char.isalpha():
        continue
    # char = char.upper()
    code = ord(char) + geser
    if char.isupper():  
      if code > ord('Z'):
        code = ord('A')
    else:
      if code > ord('z'):
        code = ord('a')
    cipher += chr(code)

print(cipher)
# Out:
# aaxaaaa
