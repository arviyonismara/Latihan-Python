# %% [markdown]
# # Print

# %%
print("Hello, World!")
print("Selamat datang di pelatihan 'FGA'")
print('selamat hari "Selasa"')
a = 3
b = "makan nasi"
c = 0.000005
print('saya %s sebanyak %d piring' % (b,a))
print('saya %s sebanyak %.2d piring' % (b,a))
print('saya %s sebanyak %.2f piring dengan biaya %.8f' % (b,a,c))
# Out:
# Hello, World!
# Selamat datang di pelatihan 'FGA'
# selamat hari "Selasa"
# saya makan nasi sebanyak 3 piring
# saya makan nasi sebanyak 03 piring
# saya makan nasi sebanyak 3.00 piring dengan biaya 0.00000500

# %% [markdown]
# harus sesuai urutan

# %%
a = 3
b = "makan nasi"
c = 0.000005
print('saya %s sebanyak %.2f piring dengan biaya %.8f' % (a,b,c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-b852ce50d221> in <module>()
#       2 b = "makan nasi"
#       3 c = 0.000005
# ----> 4 print('saya %s sebanyak %.2f piring dengan biaya %.8f' % (a,b,c))
#
# TypeError: must be real number, not str

# %% [markdown]
# sebagai argumen

# %%
a = 'saya suka makan pecel'
print(a)
# Out:
# saya suka makan pecel

# %%
b = 'saya suka minum teh manis panas'
print(a)
print()
print(b)
# Out:
# saya suka makan pecel
#
# saya suka minum teh manis panas

# %%
b = 'saya suka minum teh manis panas'
print(a)
print(' ')
print(b)
# Out:
# saya suka makan pecel
#
# saya suka minum teh manis panas

# %%
print('ada dua kalimat, kalimat pertama adalah',a,'dan kalimat kedua adalah',b)
# Out:
# ada dua kalimat, kalimat pertama adalah saya suka makan pecel dan kalimat kedua adalah saya suka minum teh manis panas

# %% [markdown]
# bentuk lain print

# %%
print(5)
print('5')
# Out:
# 5
# 5

# %%
char_a = '5'
char_b = 5
char_c = 5.0
char_d = 0.5
print(type(char_a))
print(type(char_b))
print(type(char_c))
print(type(char_d))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %%
char_e = 5,000
print(type(char_e))
# Out:
# <class 'tuple'>

# %%
char_e
# Out:
# (5, 0)

# %% [markdown]
# escape string

# %%
print("The itsy bitsy spider\nclimbed up the waterspout.")
print()
print("Down came the rain\nand washed the spider out.")
# Out:
# The itsy bitsy spider
#  climbed up the waterspout.
#
# Down came the rain
#  and washed the spider out.

# %%
print("The itsy bitsy spider\tclimbed up the waterspout.")
print()
print("Down came the rain\tand washed the spider out.")
# Out:
# The itsy bitsy spider	climbed up the waterspout.
#
# Down came the rain	and washed the spider out.

# %%
print('saya sebaiknya pergi ke paragon/novotel hotel')
# Out:
# saya sebaiknya pergi ke paragon/novotel hotel

# %%
print('saya sebaiknya pergi ke paragon\novotel hotel')
# Out:
# saya sebaiknya pergi ke paragon
# ovotel hotel

# %%
print('saya sebaiknya pergi ke paragon\\novotel hotel')
# Out:
# saya sebaiknya pergi ke paragon\novotel hotel

# %%
print("The itsy bitsy spider" , "climbed up" , "the waterspout.")
# Out:
# The itsy bitsy spider climbed up the waterspout.

# %%
a1 = 'crying'
b1 = 'hardly'
print("The itsy bitsy spider" ,a1, "climbed up" ,b1, "the waterspout.")
# Out:
# The itsy bitsy spider crying climbed up hardly the waterspout.

# %% [markdown]
# keyword argument

# %%
print("My name is", "Python.", end=" ")
print("Monty Python.")
# Out:
# My name is Python. Monty Python.

# %%
print("My name is", "Python.", end=";")
print("Monty Python.")
# Out:
# My name is Python.;Monty Python.

# %%
print("My name is", "Python.", end=" \n")
print("Monty Python.")
# Out:
# My name is Python.
# Monty Python.

# %%
print("My name is", "Python.", end=" \t")
print("Monty Python.")
# Out:
# My name is Python. 	Monty Python.

# %% [markdown]
# separator

# %%
print("My", "name", "is", "Monty", "Python.")
# Out:
# My name is Monty Python.

# %%
print("My", "name", "is", "Monty", "Python.", sep="-")
# Out:
# My-name-is-Monty-Python.

# %%
print("My", "name", "is", sep="_", end="*")
print("Monty", "Python.", sep="*", end="*\n")
# Out:
# My_name_is*Monty*Python.*

# %%
print("My", "name", "is", sep="_", end="*\n")
print("Monty", "Python.", sep="*", end="*\n")
# Out:
# My_name_is*
# Monty*Python.*

# %%
print("My", "name", "is", sep="_", end="*\\n")
print("Monty", "Python.", sep="*", end="*\n")
# Out:
# My_name_is*\nMonty*Python.*

# %% [markdown]
# print lebih lanjut

# %%
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****

# %%
# buat besar
print("     *")
print("   *  *")
print("  *    *")
print(" *      *")
print("***    ***")
print("  *    *")
print("  *    *")
print("  ******")
# Out:
#      *
#    *  *
#   *    *
#  *      *
# ***    ***
#   *    *
#   *    *
#   ******

# %% [markdown]
# # Literal

# %%
nominal = 1_000_000
print(nominal)
print(type(nominal))
# Out:
# 1000000
# <class 'int'>

# %%
nominal = -1_000_000
print(nominal)
print(type(nominal))
# Out:
# -1000000
# <class 'int'>

# %% [markdown]
# oktal (nol dan huruf O)
#
# - https://www.rapidtables.com/convert/number/octal-to-decimal.html

# %%
print(0o123)
# Out:
# 83

# %% [markdown]
# hexadecimal (nol dan huruf X)

# %%
print(0x53)
# Out:
# 83

# %%
0.4
# Out:
# 0.4

# %%
.4
# Out:
# 0.4

# %%
0.4
# Out:
# 0.4

# %%
3E8
# Out:
# 300000000.0

# %%
3e8
# Out:
# 300000000.0

# %%
0.2e8
# Out:
# 20000000.0

# %%
2e8.0
# Out:
#   File "<ipython-input-67-85d67603a3b2>", line 1
#     2e8.0
#         ^
# SyntaxError: invalid syntax

# %%
5e-3
# Out:
# 0.005

# %%
5e(-3)
# Out:
#   File "<ipython-input-69-3bf85eeaf0e4>", line 1
#     5e(-3)
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# string

# %%
print("I like "Monty Python"")
# Out:
#   File "<ipython-input-71-7f4097e7aa41>", line 1
#     print("I like "Monty Python"")
#                        ^
# SyntaxError: invalid syntax

# %%
print("I like \"Monty Python\"")
# Out:
# I like "Monty Python"

# %%
print('I like "Monty Python"')
# Out:
# I like "Monty Python"

# %%
print("I'm Monty Python.")
# Out:
# I'm Monty Python.

# %%
print('I\'m Monty Python.')
# Out:
# I'm Monty Python.

# %%
print('I"m Monty Python.')
# Out:
# I"m Monty Python.

# %% [markdown]
# boolean

# %%
print(5>3)
# Out:
# True

# %%
print(True>False)
# Out:
# True

# %%
print(False>True)
# Out:
# False

# %%
print(True<False)
# Out:
# False

# %% [markdown]
# kasus
#
# "I'm"
#
# ""learning""
#
# """Python"""

# %%
print("\"I'm\"","\"\"learning\"\"","\"\"\"Python\"\"\"", sep="\n")
# Out:
# "I'm"
# ""learning""
# """Python"""
