# %%
def tambah1(a,b):
  return a+b

def tambah2(c,d):
  return c+d

def tambahBanyak(a,b):
  return a*b

# %%
class Pegawai:
  pass

# %%
class Dosen:
  pass

# %%
alzami = Dosen()

# %%
type(alzami)
# Out:
# __main__.Dosen

# %% [markdown]
# # stack dengan prosedural approach

# %%
stack = []

# %%
def push(val):
  stack.append(val)

def pop():
  val = stack[-1]
  del stack[-1]
  return val

# %%
push(3)

# %%
stack
# Out:
# [3]

# %%
push(2)

# %%
stack
# Out:
# [3, 2]

# %%
push(1)
stack
# Out:
# [3, 2, 1]

# %%
pop()
stack
# Out:
# [3, 2]

# %%
pop()
stack
# Out:
# [3]

# %%
push(5)
stack
# Out:
# [3, 5]

# %%
stack[0] = 2
stack
# Out:
# [2, 5]

# %% [markdown]
# # stack OOP

# %%
class Stack:
  def __init__(self):
    print('halo')

# %%
satu = Stack()
# Out:
# halo

# %%
class Stack:
    def __init__(self):
        self.stack_list = []

# %%
stack_object = Stack()

# %%
print(len(stack_object.stack_list))
# Out:
# 0

# %%
class Stack2:
    def __init__(self):
        self.__stack_list = []

# %%
dua = Stack2()
print(len(dua.stack_list))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-e244cc6e42b1> in <module>()
#       1 dua = Stack2()
# ----> 2 print(len(dua.stack_list))
#
# AttributeError: 'Stack2' object has no attribute 'stack_list'

# %%
print(len(dua.__stack_list))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-59d474cf8287> in <module>()
# ----> 1 print(len(dua.__stack_list))
#
# AttributeError: 'Stack2' object has no attribute '__stack_list'

# %% [markdown]
# # OOP yang benar

# %%
class StackBenar:
  def __init__(self):
    self.__stack_list = []
  
  def push(self, val):
    self.__stack_list.append(val)
    print(self.__stack_list)
  
  def pop(self):
    val = self.__stack_list[-1]
    del self.__stack_list[-1]
    return val

# %%
benarSekali = StackBenar()

# %%
benarSekali.push(3)
# Out:
# [3]

# %%
benarSekali

# %%
print(benarSekali)
# Out:
# <__main__.StackBenar object at 0x7f72c7ae5ad0>

# %%
benarSekali.push(2)
# Out:
# [3, 2]

# %%
benarSekali.push(1)
# Out:
# [3, 2, 1]

# %%
benarSekali[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-dd172e85132f> in <module>()
# ----> 1 benarSekali[0] = 5
#
# TypeError: 'StackBenar' object does not support item assignment

# %%
print(benarSekali.pop())
# Out:
# 1

# %% [markdown]
# # lanjut

# %%
class Stack:
  def __init__(self):
    self.__stack_list = []
  
  def push(self, val):
    self.__stack_list.append(val)
    print(self.__stack_list)
  
  def pop(self):
    val = self.__stack_list[-1]
    del self.__stack_list[-1]
    return val

# %%
little_stack = Stack()
another_stack = Stack()
funny_stack = Stack()

# %%
little_stack.push(1)
# Out:
# [1]

# %%
another_stack.push(little_stack.pop() + 1)
# Out:
# [2]

# %%
funny_stack.push(another_stack.pop() - 2)
# Out:
# [0]

# %%
print(funny_stack.pop())
# Out:
# 0
